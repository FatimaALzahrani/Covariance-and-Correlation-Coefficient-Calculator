# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaALzahrani/Covariance-and-Correlation-Coefficient-Calculator/blob/main/Covariance_and_Correlation_Coefficient_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Covariance and Correlation Calculator 📈**
# Welcome to the interactive tool for calculating covariance and correlation coefficient!
# You can generate data, calculate statistics, and visualize the relationship between variables.
# Follow the steps below to explore the relationships between X and Y.

# %% [markdown]
# ##📋 **Generate Data Function**

# %% [markdown]
# This function creates two variables, X and Y, with a linear relationship and some noise.

# %%
import numpy as np

def generate_data(seed=42, n=100, noise=0.5, slope=2):
    np.random.seed(seed)
    x = np.random.randn(n)
    y = slope * x + np.random.randn(n) * noise
    return x, y

# %% [markdown]
# ## **📊 Calculate Statistics**

# %% [markdown]
# This function computes covariance, standard deviations, and the correlation coefficient.

# %%
def calculate_statistics(x, y):
    mean_x, mean_y = np.mean(x), np.mean(y)
    covariance = np.sum((x - mean_x) * (y - mean_y)) / (len(x) - 1)
    std_x, std_y = np.std(x, ddof=1), np.std(y, ddof=1)
    correlation = covariance / (std_x * std_y)
    return {
        "mean_x": mean_x,
        "mean_y": mean_y,
        "covariance": covariance,
        "std_x": std_x,
        "std_y": std_y,
        "correlation": correlation,
    }

# %% [markdown]
# ## **🎨 Scatter Plot Function**

# %% [markdown]
# This function creates a scatter plot of X and Y with mean lines and correlation.

# %%
import matplotlib.pyplot as plt

def plot_data(x, y, stats):
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, alpha=0.7, label="📍 Data Points")
    plt.axhline(stats['mean_y'], color="red", linestyle="--", label="🔴 Mean Y")
    plt.axvline(stats['mean_x'], color="blue", linestyle="--", label="🔵 Mean X")
    plt.title(f"Scatter Plot 📊 (Correlation: {stats['correlation']:.4f})")
    plt.xlabel("X-axis ➡️")
    plt.ylabel("Y-axis ⬆️")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **🌟 Main Program**

# %% [markdown]
# This cell interacts with the user to generate data, calculate statistics, and visualize results.

# %%
print("🌟 Welcome to the Covariance and Correlation Calculator 🌟")

n = int(input("🔢 Enter the number of data points (e.g., 100): "))
noise = float(input("🎛️ Enter the noise level (e.g., 0.5): "))
slope = float(input("📈 Enter the slope of the linear relationship (e.g., 2): "))
seed = int(input("🎲 Enter a random seed for reproducibility (e.g., 42): "))

x, y = generate_data(seed=seed, n=n, noise=noise, slope=slope)
stats = calculate_statistics(x, y)

print("\n📋 --Results:--")
print(f"   ➡️ Covariance: {stats['covariance']:.4f}")
print(f"   ➡️ Correlation Coefficient: {stats['correlation']:.4f}")

print("\n🔍 Visualizing your data...")
plot_data(x, y, stats)

# %% [markdown]
# ### **Strong Positive Correlation**

# %%
print("🌟 Welcome to the Covariance and Correlation Calculator 🌟")

n = int(input("🔢 Enter the number of data points (e.g., 100): "))
noise = float(input("🎛️ Enter the noise level (e.g., 0.5): "))
slope = float(input("📈 Enter the slope of the linear relationship (e.g., 2): "))
seed = int(input("🎲 Enter a random seed for reproducibility (e.g., 42): "))

x, y = generate_data(seed=seed, n=n, noise=noise, slope=slope)
stats = calculate_statistics(x, y)

print("\n📋 --Results:--")
print(f"   ➡️ Covariance: {stats['covariance']:.4f}")
print(f"   ➡️ Correlation Coefficient: {stats['correlation']:.4f}")

print("\n🔍 Visualizing your data...")
plot_data(x, y, stats)
# Out:
# 🌟 Welcome to the Covariance and Correlation Calculator 🌟
# 🔢 Enter the number of data points (e.g., 100): 200
# 🎛️ Enter the noise level (e.g., 0.5): 0.2
# 📈 Enter the slope of the linear relationship (e.g., 2): 20
# 🎲 Enter a random seed for reproducibility (e.g., 42): 45
#
# 📋 --Results:--
#    ➡️ Covariance: 18.9964
#    ➡️ Correlation Coefficient: 0.9999
#
# 🔍 Visualizing your data...
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %% [markdown]
# ### **Weak Correlation**

# %%
print("🌟 Welcome to the Covariance and Correlation Calculator 🌟")

n = int(input("🔢 Enter the number of data points (e.g., 100): "))
noise = float(input("🎛️ Enter the noise level (e.g., 0.5): "))
slope = float(input("📈 Enter the slope of the linear relationship (e.g., 2): "))
seed = int(input("🎲 Enter a random seed for reproducibility (e.g., 42): "))

x, y = generate_data(seed=seed, n=n, noise=noise, slope=slope)
stats = calculate_statistics(x, y)

print("\n📋 --Results:--")
print(f"   ➡️ Covariance: {stats['covariance']:.4f}")
print(f"   ➡️ Correlation Coefficient: {stats['correlation']:.4f}")

print("\n🔍 Visualizing your data...")
plot_data(x, y, stats)
# Out:
# 🌟 Welcome to the Covariance and Correlation Calculator 🌟
# 🔢 Enter the number of data points (e.g., 100): 300
# 🎛️ Enter the noise level (e.g., 0.5): 1
# 📈 Enter the slope of the linear relationship (e.g., 2): 0.8
# 🎲 Enter a random seed for reproducibility (e.g., 42): 45
#
# 📋 --Results:--
#    ➡️ Covariance: 0.8058
#    ➡️ Correlation Coefficient: 0.6485
#
# 🔍 Visualizing your data...
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %% [markdown]
# ### **No Correlation**

# %%
print("🌟 Welcome to the Covariance and Correlation Calculator 🌟")

n = int(input("🔢 Enter the number of data points (e.g., 100): "))
noise = float(input("🎛️ Enter the noise level (e.g., 0.5): "))
slope = float(input("📈 Enter the slope of the linear relationship (e.g., 2): "))
seed = int(input("🎲 Enter a random seed for reproducibility (e.g., 42): "))

x, y = generate_data(seed=seed, n=n, noise=noise, slope=slope)
stats = calculate_statistics(x, y)

print("\n📋 --Results:--")
print(f"   ➡️ Covariance: {stats['covariance']:.4f}")
print(f"   ➡️ Correlation Coefficient: {stats['correlation']:.4f}")

print("\n🔍 Visualizing your data...")
plot_data(x, y, stats)
# Out:
# 🌟 Welcome to the Covariance and Correlation Calculator 🌟
# 🔢 Enter the number of data points (e.g., 100): 300
# 🎛️ Enter the noise level (e.g., 0.5): 1
# 📈 Enter the slope of the linear relationship (e.g., 2): 0
# 🎲 Enter a random seed for reproducibility (e.g., 42): 45
#
# 📋 --Results:--
#    ➡️ Covariance: 0.0249
#    ➡️ Correlation Coefficient: 0.0263
#
# 🔍 Visualizing your data...
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-3-411e7ba99f84>:13: UserWarning: Glyph 128309 (\N{LARGE BLUE CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
